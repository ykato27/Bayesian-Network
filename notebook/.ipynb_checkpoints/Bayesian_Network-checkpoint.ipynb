# %%
# 必要なライブラリーのインポート
import pandas as pd
import numpy as np
import networkx as nx
import os
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston

from pgmpy.models import BayesianModel
from pgmpy.estimators import ConstraintBasedEstimator
from pgmpy.estimators import BicScore

import warnings

# %%
# データセットの読込み
boston = load_boston()

# データフレームの作成
# 説明変数の格納
df = pd.DataFrame(boston.data, columns = boston.feature_names)

# 目的変数の追加
df['MEDV'] = boston.target

# データの中身を確認
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# #### 離散値に変更
# PCアルゴリズムは連続値は扱えないため、離散値へ変更

# %%
# 離散値に変更
df_discrete = df.copy()

df_discrete['CRIM'] = pd.cut(df_discrete['CRIM'], 5)
df_discrete['ZN'] = pd.cut(df_discrete['ZN'], 5)
df_discrete['INDUS'] = pd.cut(df_discrete['INDUS'], 5)
df_discrete['CHAS'] = pd.cut(df_discrete['CHAS'], 5)
df_discrete['NOX'] = pd.cut(df_discrete['NOX'], 5)
df_discrete['RM'] = pd.cut(df_discrete['RM'], 5)
df_discrete['AGE'] = pd.cut(df_discrete['AGE'], 5)
df_discrete['DIS'] = pd.cut(df_discrete['DIS'], 5)
df_discrete['RAD'] = pd.cut(df_discrete['RAD'], 5)
df_discrete['TAX'] = pd.cut(df_discrete['TAX'], 5)
df_discrete['PTRATIO'] = pd.cut(df_discrete['PTRATIO'], 5)
df_discrete['B'] = pd.cut(df_discrete['B'], 5)
df_discrete['LSTAT'] = pd.cut(df_discrete['LSTAT'], 5)
df_discrete['MEDV'] = pd.cut(df_discrete['MEDV'], 5)

df_discrete.head()
# Out:
#               CRIM            ZN            INDUS           CHAS  \
# 0  (-0.0826, 17.8]  (-0.1, 20.0]   (0.433, 5.916]  (-0.001, 0.2]
# 1  (-0.0826, 17.8]  (-0.1, 20.0]  (5.916, 11.372]  (-0.001, 0.2]
# 2  (-0.0826, 17.8]  (-0.1, 20.0]  (5.916, 11.372]  (-0.001, 0.2]
# 3  (-0.0826, 17.8]  (-0.1, 20.0]   (0.433, 5.916]  (-0.001, 0.2]
# 4  (-0.0826, 17.8]  (-0.1, 20.0]   (0.433, 5.916]  (-0.001, 0.2]
#
#               NOX              RM             AGE             DIS  \
# 0  (0.482, 0.579]  (5.649, 6.692]  (61.16, 80.58]  (3.329, 5.528]
# 1  (0.385, 0.482]  (5.649, 6.692]  (61.16, 80.58]  (3.329, 5.528]
# 2  (0.385, 0.482]  (6.692, 7.736]  (41.74, 61.16]  (3.329, 5.528]
# 3  (0.385, 0.482]  (6.692, 7.736]  (41.74, 61.16]  (5.528, 7.728]
# 4  (0.385, 0.482]  (6.692, 7.736]  (41.74, 61.16]  (5.528, 7.728]
#
#             RAD               TAX         PTRATIO                 B  \
# 0  (0.977, 5.6]    (291.8, 396.6]  (14.48, 16.36]  (317.584, 396.9]
# 1  (0.977, 5.6]  (186.476, 291.8]  (16.36, 18.24]  (317.584, 396.9]
# 2  (0.977, 5.6]  (186.476, 291.8]  (16.36, 18.24]  (317.584, 396.9]
# 3  (0.977, 5.6]  (186.476, 291.8]  (18.24, 20.12]  (317.584, 396.9]
# 4  (0.977, 5.6]  (186.476, 291.8]  (18.24, 20.12]  (317.584, 396.9]
#
#              LSTAT          MEDV
# 0   (1.694, 8.978]  (23.0, 32.0]
# 1  (8.978, 16.226]  (14.0, 23.0]
# 2   (1.694, 8.978]  (32.0, 41.0]
# 3   (1.694, 8.978]  (32.0, 41.0]
# 4   (1.694, 8.978]  (32.0, 41.0]

# %%
est = ConstraintBasedEstimator(df_discrete)

skel, seperating_sets = est.estimate_skeleton(significance_level=0.01)
print("Undirected edges: ", skel.edges())

pdag = est.skeleton_to_pdag(skel, seperating_sets)
print("PDAG edges:", pdag.edges())

model = est.pdag_to_dag(pdag)
print("DAG edges:", model.edges())
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing ZN _|_ INDUS | ['RAD', 'PTRATIO']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing ZN _|_ INDUS | ['RAD', 'DIS']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing ZN _|_ INDUS | ['RAD', 'NOX']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing ZN _|_ NOX | ['RAD', 'DIS']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing ZN _|_ NOX | ['RAD', 'PTRATIO']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing ZN _|_ NOX | ['DIS', 'PTRATIO']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing ZN _|_ DIS | ['RAD', 'PTRATIO']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing ZN _|_ RAD | ['DIS', 'PTRATIO']. At least 1000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing INDUS _|_ NOX | ['RAD', 'TAX']. At least 960 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing INDUS _|_ NOX | ['RAD', 'PTRATIO']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing INDUS _|_ NOX | ['TAX', 'PTRATIO']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing INDUS _|_ RAD | ['NOX', 'TAX']. At least 800 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing INDUS _|_ RAD | ['NOX', 'PTRATIO']. At least 1000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing INDUS _|_ RAD | ['TAX', 'PTRATIO']. At least 800 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing INDUS _|_ TAX | ['NOX', 'PTRATIO']. At least 1500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing INDUS _|_ PTRATIO | ['TAX', 'NOX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['AGE', 'RAD']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['AGE', 'DIS']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['AGE', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['AGE', 'PTRATIO']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['RAD', 'DIS']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['RAD', 'TAX']. At least 960 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['RAD', 'PTRATIO']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['DIS', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['DIS', 'PTRATIO']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ INDUS | ['TAX', 'PTRATIO']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ AGE | ['INDUS', 'RAD']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ AGE | ['INDUS', 'DIS']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ DIS | ['RAD', 'PTRATIO']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ DIS | ['RAD', 'TAX']. At least 960 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ DIS | ['RAD', 'INDUS']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ DIS | ['PTRATIO', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ DIS | ['PTRATIO', 'INDUS']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ DIS | ['TAX', 'INDUS']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ RAD | ['TAX', 'PTRATIO']. At least 800 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ TAX | ['INDUS', 'DIS']. At least 1500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ TAX | ['INDUS', 'PTRATIO']. At least 1500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ TAX | ['DIS', 'PTRATIO']. At least 1500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ PTRATIO | ['DIS', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ PTRATIO | ['DIS', 'INDUS']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing NOX _|_ PTRATIO | ['TAX', 'INDUS']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing DIS _|_ ZN | ['NOX', 'PTRATIO']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing DIS _|_ NOX | ['ZN', 'PTRATIO']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing DIS _|_ PTRATIO | ['ZN', 'NOX']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing TAX _|_ INDUS | ['RAD', 'PTRATIO']. At least 900 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing TAX _|_ INDUS | ['RAD', 'NOX']. At least 900 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing TAX _|_ INDUS | ['PTRATIO', 'NOX']. At least 1500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing TAX _|_ NOX | ['INDUS', 'RAD']. At least 900 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing TAX _|_ RAD | ['INDUS', 'PTRATIO']. At least 750 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing TAX _|_ PTRATIO | ['RAD', 'INDUS']. At least 900 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ ZN | ['INDUS', 'RAD']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ ZN | ['INDUS', 'DIS']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ ZN | ['INDUS', 'NOX']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ ZN | ['INDUS', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ ZN | ['INDUS', 'MEDV']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['RAD', 'DIS']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['RAD', 'NOX']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['RAD', 'TAX']. At least 960 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['RAD', 'MEDV']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['DIS', 'NOX']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['DIS', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['DIS', 'MEDV']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['NOX', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['NOX', 'MEDV']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['TAX', 'MEDV']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['INDUS', 'RAD']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['INDUS', 'DIS']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['INDUS', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['INDUS', 'MEDV']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['RAD', 'DIS']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['RAD', 'TAX']. At least 960 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['RAD', 'MEDV']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['DIS', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['DIS', 'MEDV']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['TAX', 'MEDV']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ DIS | ['INDUS', 'RAD']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ DIS | ['INDUS', 'NOX']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ DIS | ['INDUS', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ DIS | ['INDUS', 'MEDV']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ RAD | ['NOX', 'MEDV']. At least 1000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ RAD | ['NOX', 'TAX']. At least 800 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ RAD | ['NOX', 'INDUS']. At least 1000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ RAD | ['MEDV', 'TAX']. At least 800 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ RAD | ['MEDV', 'INDUS']. At least 1000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ RAD | ['TAX', 'INDUS']. At least 800 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ TAX | ['NOX', 'RAD']. At least 900 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ TAX | ['NOX', 'MEDV']. At least 1500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ TAX | ['NOX', 'INDUS']. At least 1500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ TAX | ['RAD', 'MEDV']. At least 900 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ TAX | ['RAD', 'INDUS']. At least 900 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ TAX | ['MEDV', 'INDUS']. At least 1500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ MEDV | ['NOX', 'RAD']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ MEDV | ['NOX', 'TAX']. At least 1600 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ MEDV | ['NOX', 'INDUS']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ MEDV | ['RAD', 'TAX']. At least 960 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ MEDV | ['RAD', 'INDUS']. At least 1200 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing LSTAT _|_ RM | ['AGE', 'MEDV']. At least 2000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ INDUS | ['RAD', 'TAX', 'NOX']. At least 4800 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ NOX | ['RAD', 'TAX', 'INDUS']. At least 4800 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ RAD | ['INDUS', 'TAX', 'NOX']. At least 4000 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/CITests.py:92: UserWarning: Insufficient data for testing PTRATIO _|_ TAX | ['INDUS', 'RAD', 'NOX']. At least 4500 samples recommended, 506 present.
#   f"Insufficient data for testing {X} _|_ {Y} | {Z}. At least {5*num_params} samples recommended, {len(data)} present."
# Undirected edges:  [('ZN', 'DIS'), ('INDUS', 'NOX'), ('INDUS', 'TAX'), ('INDUS', 'PTRATIO'), ('NOX', 'DIS'), ('NOX', 'PTRATIO'), ('RM', 'MEDV'), ('AGE', 'LSTAT'), ('RAD', 'TAX'), ('RAD', 'PTRATIO'), ('TAX', 'PTRATIO'), ('LSTAT', 'MEDV')]
# PDAG edges: [('ZN', 'DIS'), ('INDUS', 'NOX'), ('INDUS', 'TAX'), ('INDUS', 'PTRATIO'), ('NOX', 'INDUS'), ('RM', 'MEDV'), ('AGE', 'LSTAT'), ('DIS', 'ZN'), ('DIS', 'NOX'), ('RAD', 'TAX'), ('RAD', 'PTRATIO'), ('TAX', 'INDUS'), ('TAX', 'RAD'), ('TAX', 'PTRATIO'), ('PTRATIO', 'INDUS'), ('PTRATIO', 'RAD'), ('LSTAT', 'AGE'), ('LSTAT', 'MEDV'), ('MEDV', 'RM'), ('MEDV', 'LSTAT')]
# DAG edges: [('INDUS', 'NOX'), ('INDUS', 'TAX'), ('INDUS', 'PTRATIO'), ('DIS', 'NOX'), ('DIS', 'ZN'), ('RAD', 'TAX'), ('RAD', 'PTRATIO'), ('TAX', 'PTRATIO'), ('LSTAT', 'AGE'), ('MEDV', 'RM'), ('MEDV', 'LSTAT')]
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/estimators/ConstraintBasedEstimator.py:343: UserWarning: PDAG has no faithful extension (= no oriented DAG with the same v-structures as PDAG). Remaining undirected PDAG edges oriented arbitrarily.
#   + "oriented arbitrarily."

# %%
# Undirected edges（方向性なし）可視化
G = nx.Graph()
G.add_nodes_from(df.columns) # ノード
G.add_edges_from(skel.edges()) # 辺
nx.draw_circular(G, with_labels=True, arrowsize=30, node_size=800, alpha=0.3, font_weight='bold')
plt.show()

# %%
# PDAG edges（部分的な方向性あり）可視化
PDAG_model = BayesianModel(pdag.edges())
nx.draw_circular(PDAG_model, with_labels=True, arrowsize=30, node_size=800, alpha=0.3, font_weight='bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-e559c7651d83> in <module>
#       1 # PDAG edges（部分的な方向性あり）可視化
# ----> 2 PDAG_model = BayesianModel(pdag.edges())
#       3 nx.draw_circular(PDAG_model, with_labels=True, arrowsize=30, node_size=800, alpha=0.3, font_weight='bold')
#       4 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/models/BayesianModel.py in __init__(self, ebunch)
#      95         super(BayesianModel, self).__init__()
#      96         if ebunch:
# ---> 97             self.add_edges_from(ebunch)
#      98         self.cpds = []
#      99         self.cardinalities = defaultdict(int)
#
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/base/DAG.py in add_edges_from(self, ebunch, weights)
#     265         else:
#     266             for edge in ebunch:
# --> 267                 self.add_edge(edge[0], edge[1])
#     268
#     269     def get_parents(self, node):
#
# /opt/anaconda3/lib/python3.7/site-packages/pgmpy/models/BayesianModel.py in add_edge(self, u, v, **kwargs)
#     123             raise ValueError(
#     124                 "Loops are not allowed. Adding the edge from (%s->%s) forms a loop."
# --> 125                 % (u, v)
#     126             )
#     127         else:
#
# ValueError: Loops are not allowed. Adding the edge from (NOX->INDUS) forms a loop.

# %%
# DAG edges(方向性あり)可視化
DAG_model = BayesianModel(model.edges())
nx.draw_circular(DAG_model, with_labels=True, arrowsize=30, node_size=800, alpha=0.3, font_weight='bold')
plt.show()
